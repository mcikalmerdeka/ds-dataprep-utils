# %% [markdown]
# # Utils Usage for Regression Tasks

# %%
import os
import sys
from pathlib import Path

# Add root folder to path (for module imports)
sys.path.insert(0, str(Path.cwd().parent))

# Change working directory (for I/O operations)
os.chdir(Path.cwd().parent)

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Import utils scripts
from utils.preprocessing import *

# %%
# Read data
df = pd.read_csv('data/regression_data.csv')

# Preview data
display(df.head())
# Out:
#   property_id  sqft_living      sqft_lot  bedrooms  bathrooms  floors  \
# 0  PROP_00352  2074.974764  12666.739468         3        2.5     2.0
# 1  PROP_00689  1207.077982   7376.062644         2        2.0     2.0
# 2  PROP_00485  3314.232769   2414.299701         2        4.0     3.0
# 3  PROP_00388  2388.756396  10702.211271         2        2.0     2.0
# 4  PROP_00031  1186.961252   5917.575635         1        2.0     2.0
#
#    year_built  year_renovated  condition  grade  ...     city  zipcode  \
# 0      2023.0             0.0          3    6.0  ...    Other    98157
# 1      1968.0          1996.0          2    7.0  ...  Seattle    98100
# 2      1920.0             0.0          3    6.0  ...    Other    98162
# 3      2007.0          2020.0          3    8.0  ...  Seattle    98196
# 4      1996.0             0.0          1    9.0  ...  Seattle    98045
#
#     latitude   longitude  distance_to_downtown  school_rating  crime_rate  \
# 0  47.312479 -121.844119              5.396556            9.2    0.611506
# 1  47.733808 -122.010631             23.112477            4.2    5.565608
# 2  47.319195 -122.238151              8.284677            3.5    8.725351
# 3  47.111920 -121.573947              3.453021            8.6    3.260463
# 4  47.283425 -122.111706              1.565135            6.5    0.751626
#
#    has_garage  sqft_basement          price
# 0         Yes     608.974799  661229.682478
# 1        TRUE       0.000000  583489.046289
# 2           0     636.105980  759121.224769
# 3         Yes       0.000000            NaN
# 4           1       0.000000  603385.593403
#
# [5 rows x 22 columns]

# %%
# Check data information
info_df = check_data_information(df, df.columns.tolist())
display(info_df)
# Out:
#                  Feature Data Type  Null Values  Null Percentage  \
# 0            property_id    object            0             0.00
# 1            sqft_living   float64           92             8.76
# 2               sqft_lot   float64           85             8.10
# 3               bedrooms     int64            0             0.00
# 4              bathrooms   float64            0             0.00
# 5                 floors   float64            0             0.00
# 6             year_built   float64           81             7.71
# 7         year_renovated   float64           83             7.90
# 8              condition     int64            0             0.00
# 9                  grade   float64           90             8.57
# 10            waterfront    object            0             0.00
# 11                  view     int64            0             0.00
# 12                  city    object            0             0.00
# 13               zipcode     int64            0             0.00
# 14              latitude   float64            0             0.00
# 15             longitude   float64            0             0.00
# 16  distance_to_downtown   float64            0             0.00
# 17         school_rating   float64           86             8.19
# 18            crime_rate   float64           81             7.71
# 19            has_garage    object            0             0.00
# 20         sqft_basement   float64           79             7.52
# 21                 price   float64           78             7.43
#
#     Duplicated Values  Unique Values  \
# 0                  50           1000
# 1                  50            913
# 2                  50            919
# 3                  50             13
# 4                  50              9
# 5                  50              5
# 6                  50            104
# 7                  50             44
# 8                  50              5
# 9                  50             13
# 10                 50              5
# 11                 50              5
# 12                 50              8
# 13                 50            197
# 14                 50           1000
# 15                 50           1000
# 16                 50           1000
# 17                 50             74
# 18                 50            922
# 19                 50              6
# 20                 50            572
# 21                 50            920
#
#                                         Unique Sample
# 0   PROP_00352, PROP_00689, PROP_00485, PROP_00388...
# 1   2074.9747640549976, 1207.0779821460708, 3314.2...
# 2   12666.73946770685, 7376.06264433528, 2414.2997...
# 3                                       3, 2, 1, 7, 6
# 4                             2.5, 2.0, 4.0, 3.0, 1.5
# 5                             2.0, 3.0, 1.0, 2.5, 1.5
# 6              2023.0, 1968.0, 1920.0, 2007.0, 1996.0
# 7                 0.0, 1996.0, 2020.0, 1994.0, 2019.0
# 8                                       3, 2, 1, 4, 5
# 9                            6.0, 7.0, 8.0, 9.0, 11.0
# 10                                 0, Yes, 1, No, yes
# 11                                      0, 2, 3, 1, 4
# 12          Other, Seattle, Redmond, BELLEVUE, Tacoma
# 13                  98157, 98100, 98162, 98196, 98045
# 14  47.31247895396283, 47.73380798116191, 47.31919...
# 15  -121.84411878435417, -122.01063124848298, -122...
# 16  5.396556342179616, 23.112477090274368, 8.28467...
# 17                            9.2, 4.2, 3.5, 8.6, 6.5
# 18  0.6115061914546189, 5.56560795848362, 8.725351...
# 19                                Yes, TRUE, 0, 1, No
# 20  608.9747985385675, 0.0, 636.1059800711031, 679...
# 21  661229.6824781032, 583489.0462892891, 759121.2...
